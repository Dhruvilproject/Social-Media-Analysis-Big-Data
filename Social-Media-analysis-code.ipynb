# %%
# !pip install pyvis
# Out:
# Requirement already satisfied: pyvis in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from pyvis) (8.14.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from pyvis) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from pyvis) (3.0.4)
# Requirement already satisfied: networkx>=1.11 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from pyvis) (3.3)
# Requirement already satisfied: backcall in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (5.9.0)
# Requirement already satisfied: colorama in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=2.9.6->pyvis) (2.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six in c:\users\aditya chakravarty\appdata\local\programs\python\python311\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)

# %%
# packages

# standard
import numpy as np
import pandas as pd
import time

# plots
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# graph
import networkx as nx
from pyvis.network import Network

# %%
# load edge data
t1 = time.time()
df = pd.read_csv('edges.csv', 
                 header=None, names=['Follower','Target'])
t2 = time.time()
print('Elapsed time [s]: ', np.round(t2-t1,2))
# Out:
# Elapsed time [s]:  58.21

# %%
# preview
df
# Out:
#           Follower   Target
# 0                1    11553
# 1                1  8762940
# 2                1  8762941
# 3                1   688136
# 4                1  8762942
# ...            ...      ...
# 85331840   8762935   143150
# 85331841   8762936  8217613
# 85331842   8762937  8217613
# 85331843   8762938  8217613
# 85331844   8762939   150686
#
# [85331845 rows x 2 columns]

# %%
follower = 1
df_select = df[df.Follower==follower]
df_select
# Out:
#    Follower   Target
# 0         1    11553
# 1         1  8762940
# 2         1  8762941
# 3         1   688136
# 4         1  8762942

# %%
# create graph from edges
G = nx.from_pandas_edgelist(df_select, 'Follower', 'Target', create_using=nx.DiGraph())
# and plot
nx.draw(G, with_labels=True, node_size=1000, alpha=0.5, arrows=True)
plt.title('Targets that ' + str(follower) + ' follows')
plt.show()

# %%
target = 3
df_select = df[df.Target==target]
df_select
# Out:
#           Follower  Target
# 48155330         4       3
# 48156324         5       3
# 48158275         6       3
# 48159154         7       3
# 48159192         8       3
# 48159607         9       3
# 48160511        10       3
# 48160552        11       3
# 48161203        12       3
# 48161254        13       3
# 48162633        14       3
# 48164937        15       3
# 48164997        16       3
# 48165970        17       3
# 48167390        18       3
# 48167428        19       3

# %%
# create graph from edges
G = nx.from_pandas_edgelist(df_select, 'Follower', 'Target', create_using=nx.DiGraph())
# and plot
nx.draw(G, with_labels=True, node_size=1000, alpha=0.5, arrows=True)
plt.title('Followers of target ' + str(target))
plt.show()

# %%
user = 100
df_out = df[df.Follower==user]
df_in = df[df.Target==user]
df_select = pd.concat([df_in,df_out])
df_select
# Out:
#           Follower  Target
# 6769913     777202     100
# 21657538    126698     100
# 21930021       699     100
# 21963858    245669     100
# 23000793      8079     100
# 30902596    626186     100
# 48182361       100      41
# 48182362       100   22756
# 48182363       100   85690
# 48182364       100  777202
# 48182365       100  533454
# 48182366       100  700606
# 48182367       100  126698
# 48182368       100     699
# 48182369       100  245669
# 48182370       100    8079

# %%
# create graph from edges
G = nx.from_pandas_edgelist(df_select, 'Follower', 'Target', create_using=nx.DiGraph())
# and plot
nx.draw_circular(G, with_labels=True, node_size=1000, alpha=0.5, arrows=True)
plt.title('Bidirectional view of user ' + str(user))
plt.show()

# %%
net = Network(notebook=True, width='800px', height='500px')
net.directed = True
net.from_nx(G)
net.show('example.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# example.html
#         <iframe
#             width="800px"
#             height="500px"
#             src="example.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# frequency table
f_counts = df.Follower.value_counts().rename_axis('Follower').reset_index(name='Frequency')

# top 10
f_counts[0:10]
# Out:
#    Follower  Frequency
# 0      3493     214381
# 1      1693     201006
# 2      3402     180373
# 3      4018     165718
# 4     16201     156819
# 5      1450     151391
# 6      3487     147329
# 7     55567     137135
# 8     56382     131936
# 9    132335     123533

# %%
# stats
f_counts.Frequency.describe()
# Out:
# count    8.768419e+06
# mean     9.731725e+00
# std      3.410203e+02
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      2.143810e+05
# Name: Frequency, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming f_counts.Frequency contains the data
plt.hist(np.log10(1 + f_counts.Frequency), bins=100, color='pink')  # Set the color to blue
plt.yscale('log')
plt.grid(True)
plt.title('Distribution of following count')
plt.xlabel('log10(1+counts)')
plt.show()

# %%
# frequency table
t_counts = df.Target.value_counts().rename_axis('Target').reset_index(name='Frequency')

# top 10
t_counts[0:10]
# Out:
#     Target  Frequency
# 0  5994113     564512
# 1     7496     350885
# 2  1349110     341963
# 3     3493     212494
# 4     3402     196882
# 5  1629776     172231
# 6     4018     158041
# 7  8121005     155967
# 8  2041453     152689
# 9    16201     148619

# %%
# stats
t_counts.Frequency.describe()
# Out:
# count    6.626985e+06
# mean     1.287642e+01
# std      5.378080e+02
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      3.000000e+00
# max      5.645120e+05
# Name: Frequency, dtype: float64

# %%
# plot in log scale
plt.hist(np.log10(1+t_counts.Frequency),100)
plt.yscale('log')
plt.grid()
plt.title('Distribution of target count')
plt.xlabel('log10(1+counts)')
plt.show()

# %%
# select subset
df_sub = df.sample(100000, random_state=987)

# %%
# build graph from data frame
G = nx.from_pandas_edgelist(df_sub, 'Follower', 'Target', create_using=nx.DiGraph())

# %%
# calc pagerank for each node
pageranks = nx.pagerank(G)

# convert to data frame
pageranks = pd.DataFrame.from_dict(pageranks, orient='index',
                                  columns=['Pagerank'])
# and sort by pagerank
pageranks = pageranks.sort_values(by=['Pagerank'], ascending=False)

# %%
# show top 10
pageranks[0:10]
# Out:
#          Pagerank
# 5994113  0.003268
# 1928416  0.002417
# 7496     0.002098
# 1349110  0.001749
# 3493     0.001104
# 3402     0.001036
# 1629776  0.000979
# 2041453  0.000869
# 4018     0.000866
# 8121005  0.000847

# %%
# frequency table / top 10
t_counts_sub = df_sub.Target.value_counts().rename_axis('Target').reset_index(name='Frequency')
t_counts_sub[0:10]
# Out:
#     Target  Frequency
# 0  5994113        695
# 1     7496        448
# 2  1349110        372
# 3     3493        236
# 4     3402        216
# 5  1629776        200
# 6  2041453        187
# 7     4018        185
# 8  8121005        179
# 9   216481        164
